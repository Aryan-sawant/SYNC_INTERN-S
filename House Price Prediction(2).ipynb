# %% [markdown]
# **Uploading the csv File**

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-3937699e-02f7-4f83-b77b-61e54fb043c6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3937699e-02f7-4f83-b77b-61e54fb043c6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
data = pd.read_csv('data.csv')

# %%
data
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
# Required Independent Variables
x=data[['bedrooms','bathrooms','sqft_living','sqft_lot','floors','sqft_basement']]
x
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  sqft_basement
# 0          3.0       1.50         1340      7912     1.5              0
# 1          5.0       2.50         3650      9050     2.0            280
# 2          3.0       2.00         1930     11947     1.0              0
# 3          3.0       2.25         2000      8030     1.0           1000
# 4          4.0       2.50         1940     10500     1.0            800
# ...        ...        ...          ...       ...     ...            ...
# 4595       3.0       1.75         1510      6360     1.0              0
# 4596       3.0       2.50         1460      7573     2.0              0
# 4597       3.0       2.50         3010      7014     2.0              0
# 4598       4.0       2.00         2090      6630     1.0           1020
# 4599       3.0       2.50         1490      8102     2.0              0
#
# [4600 rows x 6 columns]

# %%
# Required Dependent Variable
y=data[['price']]
y
# Out:
#              price
# 0     3.130000e+05
# 1     2.384000e+06
# 2     3.420000e+05
# 3     4.200000e+05
# 4     5.500000e+05
# ...            ...
# 4595  3.081667e+05
# 4596  5.343333e+05
# 4597  4.169042e+05
# 4598  2.034000e+05
# 4599  2.206000e+05
#
# [4600 rows x 1 columns]

# %% [markdown]
# **Using Linear Regression Algorithm**

# %%
#Training and Testing the model
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
#Splitting the data into 80% training and 20% testing
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
y_pred
# Out:
# array([[ 561988.15361102],
#        [ 643510.12068547],
#        [ 267498.76418635],
#        [ 577488.99814763],
#        [ 698519.47076687],
#        [ 264556.10891449],
#        [ 675291.27468208],
#        [ 543787.31863175],
#        [ 465670.7650577 ],
#        [1042216.61725798],
#        [ 625312.53072869],
#        [ 521037.18149346],
#        [1069665.91934826],
#        [ 581496.44340468],
#        [ 687711.76518868],
#        [ 221968.88315153],
#        [ 426312.08331146],
#        [ 489557.62561102],
#        [ 992650.65218425],
#        [ 350288.12697951],
#        [ 427536.56347984],
#        [ 707870.05518818],
#        [ 287491.26822047],
#        [ 447699.0559666 ],
#        [ 758972.19551448],
#        [ 466903.71137499],
#        [ 557592.43102367],
#        [ 631972.14492951],
#        [ 291680.47435248],
#        [ 687741.92350706],
#        [ 442217.92475643],
#        [ 459591.06489564],
#        [ 410329.07348529],
#        [ 611507.45120844],
# ...

# %%
#Calculating mse,r2,rmse and mae
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
import numpy as np

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
print(f"Root Mean Square Error: {rmse}")
print(f"Mean Absolute Error: {mae}")
# Out:
# Mean Squared Error: 77568044499.09087
# R-squared: 0.47570887919825255
# Root Mean Square Error: 278510.40285614267
# Mean Absolute Error: 176812.58415200314

# %% [markdown]
# **Predicting House Prices**

# %%
import numpy as np

# Ask the user for input
num_bedrooms = float(input("Enter the number of bedrooms: "))
num_bathrooms = float(input("Enter the number of bathrooms: "))
living_room_sqft = float(input("Enter the living room area in square feet: "))
sqft_lot=float(input('Enter the lot area in square feet:'))
floors=float(input('Enter the number of floors:'))
sqft_basement=float(input('Enter the basement area in square feet:'))
# Create a feature vector for prediction
input_features = np.array([num_bedrooms,num_bathrooms,living_room_sqft,sqft_lot,floors,sqft_basement]).reshape(1, -1)

# Use your trained model to make a prediction
predicted = model.predict(input_features)

print(f'Predicted Price for the new house is ${predicted[0][0]}')
# Out:
# Enter the number of bedrooms: 3
# Enter the number of bathrooms: 2
# Enter the living room area in square feet: 200
# Enter the lot area in square feet:1500
# Enter the number of floors:2
# Enter the basement area in square feet:1200
# Predicted Price for the new house is $121053.59625969492
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
